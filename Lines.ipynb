# %% [markdown]
# <a href="https://colab.research.google.com/github/Gozalab/Math-2024-25-Winter/blob/main/Lines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notes on Lines and Tasks
#
# ### General Notes on Lines:
#
# 1. **Equation of a Line (Slope-Intercept Form):**
#    $$
#    y = mx + c
#    $$
#    - \(m\) is the slope of the line.
#    - \(c\) is the y-intercept.
#
# 2. **Point-Slope Form:**
#    $$
#    y - y_1 = m(x - x_1)
#    $$
#    - For a line passing through a point \((x_1, y_1)\) with slope \(m\).
#
# 3. **General Form:**
#    $$
#    Ax + By + C = 0
#    $$
#    - Where \(A, B, C\) are constants.
#
# 4. **Perpendicular Lines:**
#    - Slopes are negative reciprocals:
#      $$
#      m_1 \cdot m_2 = -1
#      $$
#
# 5. **Parallel Lines:**
#    - Have the same slope:
#      $$
#      m_1 = m_2
#      $$
#
# 6. **Distance from a Point to a Line:**
#    $$
#    d = \frac{|Ax_1 + By_1 + C|}{\sqrt{A^2 + B^2}}
#    $$
#    - For a point \((x_1, y_1)\) and a line \(Ax + By + C = 0\).
#
# 7. **Angle Between Two Lines:**
#    $$
#    \tan \theta = \left| \frac{m_1 - m_2}{1 + m_1 \cdot m_2} \right|
#    $$
#    - \(m_1, m_2\) are the slopes of the lines.
#
# 8. **Vector Form of a Line:**
#    - Direction vector \(\vec{v}\) indicates the direction of the line.
#    - A line parallel to \(\vec{v} = [a, b]\) through a point \((x_1, y_1)\) can be written as:
#      $$
#      \frac{x - x_1}{a} = \frac{y - y_1}{b}
#      $$
#
# ---
#
# ### Tasks and Their Solutions:
#
# #### **1. Line through \(A(1, 2)\) and \(B(3, 4)\):**
# - **Slope:**
#   $$
#   m = \frac{y_2 - y_1}{x_2 - x_1} = \frac{4 - 2}{3 - 1} = 1
#   $$
# - **Equation:**
#   Using point-slope form with point \(A(1, 2)\):
#   $$
#   y - 2 = 1(x - 1) \implies y = x + 1
#   $$
#
# ---
#
# #### **2. Line through \(A(1, 2)\) parallel to \(y = 2x + 3\):**
# - Parallel lines have the same slope (\(m = 2\)).
# - Using point-slope form:
#   $$
#   y - 2 = 2(x - 1) \implies y = 2x
#   $$
#
# ---
#
# #### **3. Line through \(A(1, 2)\) perpendicular to \(y = 2x + 3\):**
# - Slope of perpendicular line:
#   $$
#   m = -\frac{1}{2}
#   $$
# - Using point-slope form:
#   $$
#   y - 2 = -\frac{1}{2}(x - 1) \implies y = -\frac{1}{2}x + \frac{5}{2}
#   $$
#
# ---
#
# #### **4. Intersection of \(y = 2x + 3\) and \(y = 3x + 2\):**
# - Solve:
#   $$
#   2x + 3 = 3x + 2 \implies x = 1, \, y = 5
#   $$
# - Intersection point: \((1, 5)\).
# - **Angle Between the Lines:**
#   $$
#   \tan \theta = \left| \frac{2 - 3}{1 + 2 \cdot 3} \right| = \frac{1}{7}
#   $$
#
# ---
#
# #### **5. Line through \(A(1, 2)\) parallel to \(\vec{v} = [2, 3]\):**
# - Vector form:
#   $$
#   \frac{x - 1}{2} = \frac{y - 2}{3}
#   $$
# - Parametric form:
#   $$
#   x = 1 + 2t, \, y = 2 + 3t
#   $$
#
# ---
#
# #### **6. Lines Parallel and Perpendicular to \(y = 2x + 3\):**
# - **Parallel Line:**
#   $$
#   y = 2x + c
#   $$
#   For example, \(y = 2x + 1\).
# - **Perpendicular Line:**
#   $$
#   y = -\frac{1}{2}x + c
#   $$
#   For example, \(y = -\frac{1}{2}x\).
#
# ---
#
# #### **7. Distance from \(A(1, 2)\) to \(y = 2x + 3\):**
# - Rewrite line as:
#   $$
#   2x - y + 3 = 0
#   $$
# - Use the distance formula:
#   $$
#   d = \frac{|2 \cdot 1 - 1 \cdot 2 + 3|}{\sqrt{2^2 + (-1)^2}} = \frac{3}{\sqrt{5}}
#   $$
#
# ---
#
# #### **8. Line intersects axes at \(A(2, 0)\) and \(B(0, 3)\):**
# - Slope:
#   $$
#   m = \frac{3 - 0}{0 - 2} = -\frac{3}{2}
#   $$
# - Equation using point-slope form:
#   $$
#   y = -\frac{3}{2}x + 3
#   $$
#
# ---
#
# #### **9. Angle Between \(y = x + 3\) and the \(Ox\)-Axis:**
# - Slope is \(m = 1\).
# - Angle:
#   $$
#   \tan \theta = |1| \implies \theta = 45^\circ
#   $$
#
# ---
#
# #### **10. Vector Perpendicular to \(x + y + 1 = 0\):**
# - Direction vector of the line: \([-1, -1]\).
# - Perpendicular vector: \([1, -1]\) or \([-1, 1]\).
#
#
# **Visualize each task.** - Python, GeoGebra, Wolfram Alpha, ...
#
# * The line passes through points $A(1, 2)$ and $B(3, 4)$. Find the equation of the line.
# * The line passes through point $A(1, 2)$ and is parallel to the line $y = 2x + 3$. Find the equation of the line.
# * The line passes through point $A(1, 2)$ and is perpendicular to the line $y = 2x + 3$. Find the equation of the line.
# * We have two lines $y = 2x + 3$ and $y = 3x + 2$. Find the intersection point of these lines and calculate the angle between them.
# * Write the equation of the line passing through point $A(1, 2)$ and parallel to the vector $\vec{v} = [2, 3]$.
# * We have the line $y = 2x + 3$. Find an example of a line perpendicular and parallel to it.
# * We have the line $y = 2x + 3$ and point $A(1, 2)$. Find the distance from point $A$ to the line.
# * The line intersects the coordinate axes at points $A(2, 0)$ and $B(0, 3)$. Find the equation of the line.
# * Calculate the angle between the line $y = x + 3$ and the $Ox$ axis.
# * Provide a vector perpendicular to the line $x + y + 1 = 0$.
